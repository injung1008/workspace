# %%
import sys
import time
import torch
from torch.backends import cudnn
import cv2
from PIL import Image
import numpy as np
import torchvision
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
# import transforms
import torchvision.transforms as transforms
import os

import torchvision.transforms.functional as TF

DEVICE = torch.device('cuda')


#modeling
class BottleNeck(nn.Module):
    expansion = 4
    Cardinality = 32 # group 수
    Basewidth = 64 # bottleneck 채널이 64이면 group convolution의 채널은 depth가 됩니다.
    Depth = 4 # basewidth일 때, group convolution의 채널 수
    def __init__(self, in_channels, out_channels, stride=1):
        super().__init__()
        C = BottleNeck.Cardinality
        D = int(BottleNeck.Depth * out_channels / BottleNeck.Basewidth)

        self.conv_residual = nn.Sequential(
            nn.Conv2d(in_channels, C * D, 1, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(C*D),
            nn.ReLU(),
            nn.Conv2d(C*D, C*D, 3, stride=stride, padding=1, groups=BottleNeck.Cardinality, bias=False),
            nn.BatchNorm2d(C*D),
            nn.ReLU(),
            nn.Conv2d(C*D, out_channels * BottleNeck.expansion, 1, stride=1, padding=0, bias=False),
            nn.BatchNorm2d(out_channels * BottleNeck.expansion)
        )

        self.conv_shortcut = nn.Sequential()

        if stride != 1 or in_channels != out_channels * BottleNeck.expansion:
            self.conv_shortcut = nn.Conv2d(in_channels, out_channels * BottleNeck.expansion, 1, stride=stride, padding=0)

    def forward(self, x):
        x = self.conv_residual(x) + self.conv_shortcut(x)
        return x


# ResNext
class ResNext(nn.Module):
    def __init__(self, nblocks, num_classes=2, init_weights=True):
        super().__init__()
        self.init_weights=init_weights
        self.in_channels = 64

        self.conv1 = nn.Sequential(
            nn.Conv2d(3, 64, 7, stride=2, padding=2, bias=False),
            nn.BatchNorm2d(64),
            nn.ReLU(),
            nn.MaxPool2d(3, stride=2, padding=1)
        )

        self.conv2 = self._make_res_block(nblocks[0], 64, 1)
        self.conv3 = self._make_res_block(nblocks[1], 128, 2)
        self.conv4 = self._make_res_block(nblocks[2], 256, 2)
        self.conv5 = self._make_res_block(nblocks[3], 512, 2)

        self.avg_pool = nn.AdaptiveAvgPool2d((1,1))
        self.linear = nn.Linear(512 * BottleNeck.expansion, num_classes)

        # weights initialization
        if self.init_weights:
            self._initialize_weights()

    def forward(self, x):
        x = self.conv1(x)
        x = self.conv2(x)
        x = self.conv3(x)
        x = self.conv4(x)
        x = self.conv5(x)
        x = self.avg_pool(x)
        x = x.view(x.size(0), -1)
        x = self.linear(x)
        return x

    def _make_res_block(self, nblock, out_channels, stride):
        strides = [stride] + [1] * (nblock-1)
        res_block = nn.Sequential()
        for i, stride in enumerate(strides):
            res_block.add_module('dens_layer_{}'.format(i), BottleNeck(self.in_channels, out_channels, stride))
            self.in_channels = out_channels * BottleNeck.expansion
        return res_block

    # weights initialization function
    def _initialize_weights(self):
        for m in self.modules():
            if isinstance(m, nn.Conv2d):
                nn.init.kaiming_normal_(m.weight, mode='fan_out', nonlinearity='relu')
                if m.bias is not None:
                    nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.BatchNorm2d):
                nn.init.constant_(m.weight, 1)
                nn.init.constant_(m.bias, 0)
            elif isinstance(m, nn.Linear):
                nn.init.normal_(m.weight, 0, 0.01)
                nn.init.constant_(m.bias, 0)

def ResNext50():
    return ResNext([3, 4, 6, 3])


DEVICE = torch.device('cuda')

path2weights = '/DATA_17/ij/trt_inference/make_trt/res_256_256.pt'

batch_size = 1

input = torch.randn(batch_size,3, 256, 256).cuda()  #배치, 채널, 세로(h), 가로(w)

model = ResNext50().to(DEVICE)
model.load_state_dict(torch.load(path2weights))
model.eval()

output = model(input)




## pytorch to onnx 
torch.onnx.export(
    model,                                # model being run
    input,    # model input (or a tuple for multiple inputs)
    "helmet_resnext.onnx", # where to save the model (can be a file or file-like object)
    verbose=True, 
    opset_version=11,
    input_names = ['input'],              # the model's input names
    output_names = ['output'],
    dynamic_axes = {'input' : {0 : 'batch_size'},
                    'output' : {0 : 'batch_size'}}
)            # the model's output names
# Out:
# graph(%input : Float(*, 3, 256, 256, strides=[196608, 65536, 256, 1], requires_grad=0, device=cuda:0),
#       %conv2.dens_layer_0.conv_shortcut.weight : Float(256, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %conv2.dens_layer_0.conv_shortcut.bias : Float(256, strides=[1], requires_grad=1, device=cuda:0),
#       %conv3.dens_layer_0.conv_shortcut.weight : Float(512, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %conv3.dens_layer_0.conv_shortcut.bias : Float(512, strides=[1], requires_grad=1, device=cuda:0),
#       %conv4.dens_layer_0.conv_shortcut.weight : Float(1024, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %conv4.dens_layer_0.conv_shortcut.bias : Float(1024, strides=[1], requires_grad=1, device=cuda:0),
#       %conv5.dens_layer_0.conv_shortcut.weight : Float(2048, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %conv5.dens_layer_0.conv_shortcut.bias : Float(2048, strides=[1], requires_grad=1, device=cuda:0),
#       %linear.weight : Float(2, 2048, strides=[2048, 1], requires_grad=1, device=cuda:0),
#       %linear.bias : Float(2, strides=[1], requires_grad=1, device=cuda:0),
#       %468 : Float(64, 3, 7, 7, strides=[147, 49, 7, 1], requires_grad=0, device=cuda:0),
#       %469 : Float(64, strides=[1], requires_grad=0, device=cuda:0),
#       %471 : Float(128, 64, 1, 1, strides=[64, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %472 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %474 : Float(128, 4, 3, 3, strides=[36, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %475 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %477 : Float(256, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %478 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %480 : Float(128, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %481 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %483 : Float(128, 4, 3, 3, strides=[36, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %484 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %486 : Float(256, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %487 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %489 : Float(128, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %490 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %492 : Float(128, 4, 3, 3, strides=[36, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %493 : Float(128, strides=[1], requires_grad=0, device=cuda:0),
#       %495 : Float(256, 128, 1, 1, strides=[128, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %496 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %498 : Float(256, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %499 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %501 : Float(256, 8, 3, 3, strides=[72, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %502 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %504 : Float(512, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %505 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %507 : Float(256, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %508 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %510 : Float(256, 8, 3, 3, strides=[72, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %511 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %513 : Float(512, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %514 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %516 : Float(256, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %517 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %519 : Float(256, 8, 3, 3, strides=[72, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %520 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %522 : Float(512, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %523 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %525 : Float(256, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %526 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %528 : Float(256, 8, 3, 3, strides=[72, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %529 : Float(256, strides=[1], requires_grad=0, device=cuda:0),
#       %531 : Float(512, 256, 1, 1, strides=[256, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %532 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %534 : Float(512, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %535 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %537 : Float(512, 16, 3, 3, strides=[144, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %538 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %540 : Float(1024, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %541 : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %543 : Float(512, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %544 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %546 : Float(512, 16, 3, 3, strides=[144, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %547 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %549 : Float(1024, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %550 : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %552 : Float(512, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %553 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %555 : Float(512, 16, 3, 3, strides=[144, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %556 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %558 : Float(1024, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %559 : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %561 : Float(512, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %562 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %564 : Float(512, 16, 3, 3, strides=[144, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %565 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %567 : Float(1024, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %568 : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %570 : Float(512, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %571 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %573 : Float(512, 16, 3, 3, strides=[144, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %574 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %576 : Float(1024, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %577 : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %579 : Float(512, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %580 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %582 : Float(512, 16, 3, 3, strides=[144, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %583 : Float(512, strides=[1], requires_grad=0, device=cuda:0),
#       %585 : Float(1024, 512, 1, 1, strides=[512, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %586 : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %588 : Float(1024, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %589 : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %591 : Float(1024, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %592 : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %594 : Float(2048, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %595 : Float(2048, strides=[1], requires_grad=0, device=cuda:0),
#       %597 : Float(1024, 2048, 1, 1, strides=[2048, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %598 : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %600 : Float(1024, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %601 : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %603 : Float(2048, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %604 : Float(2048, strides=[1], requires_grad=0, device=cuda:0),
#       %606 : Float(1024, 2048, 1, 1, strides=[2048, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %607 : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %609 : Float(1024, 32, 3, 3, strides=[288, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %610 : Float(1024, strides=[1], requires_grad=0, device=cuda:0),
#       %612 : Float(2048, 1024, 1, 1, strides=[1024, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %613 : Float(2048, strides=[1], requires_grad=0, device=cuda:0),
#       %614 : Long(1, strides=[1], requires_grad=0, device=cpu)):
#   %467 : Float(*, 64, 127, 127, strides=[1032256, 16129, 127, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[7, 7], pads=[2, 2, 2, 2], strides=[2, 2]](%input, %468, %469)
#   %307 : Float(*, 64, 127, 127, strides=[1032256, 16129, 127, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%467) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %308 : Float(*, 64, 64, 64, strides=[262144, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::MaxPool[ceil_mode=0, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%307) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:719:0
#   %470 : Float(*, 128, 64, 64, strides=[524288, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%308, %471, %472)
#   %311 : Float(*, 128, 64, 64, strides=[524288, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%470) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %473 : Float(*, 128, 64, 64, strides=[524288, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%311, %474, %475)
#   %314 : Float(*, 128, 64, 64, strides=[524288, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%473) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %476 : Float(*, 256, 64, 64, strides=[1048576, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%314, %477, %478)
#   %317 : Float(*, 256, 64, 64, strides=[1048576, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%308, %conv2.dens_layer_0.conv_shortcut.weight, %conv2.dens_layer_0.conv_shortcut.bias) # /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py:443:0
#   %318 : Float(*, 256, 64, 64, strides=[1048576, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Add(%476, %317) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %479 : Float(*, 128, 64, 64, strides=[524288, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%318, %480, %481)
#   %321 : Float(*, 128, 64, 64, strides=[524288, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%479) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %482 : Float(*, 128, 64, 64, strides=[524288, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%321, %483, %484)
#   %324 : Float(*, 128, 64, 64, strides=[524288, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%482) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %485 : Float(*, 256, 64, 64, strides=[1048576, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%324, %486, %487)
#   %327 : Float(*, 256, 64, 64, strides=[1048576, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Add(%485, %318) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %488 : Float(*, 128, 64, 64, strides=[524288, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%327, %489, %490)
#   %330 : Float(*, 128, 64, 64, strides=[524288, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%488) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %491 : Float(*, 128, 64, 64, strides=[524288, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%330, %492, %493)
#   %333 : Float(*, 128, 64, 64, strides=[524288, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%491) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %494 : Float(*, 256, 64, 64, strides=[1048576, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%333, %495, %496)
#   %336 : Float(*, 256, 64, 64, strides=[1048576, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Add(%494, %327) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %497 : Float(*, 256, 64, 64, strides=[1048576, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%336, %498, %499)
#   %339 : Float(*, 256, 64, 64, strides=[1048576, 4096, 64, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%497) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %500 : Float(*, 256, 32, 32, strides=[262144, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%339, %501, %502)
#   %342 : Float(*, 256, 32, 32, strides=[262144, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%500) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %503 : Float(*, 512, 32, 32, strides=[524288, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%342, %504, %505)
#   %345 : Float(*, 512, 32, 32, strides=[524288, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%336, %conv3.dens_layer_0.conv_shortcut.weight, %conv3.dens_layer_0.conv_shortcut.bias) # /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py:443:0
#   %346 : Float(*, 512, 32, 32, strides=[524288, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Add(%503, %345) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %506 : Float(*, 256, 32, 32, strides=[262144, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%346, %507, %508)
#   %349 : Float(*, 256, 32, 32, strides=[262144, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%506) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %509 : Float(*, 256, 32, 32, strides=[262144, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%349, %510, %511)
#   %352 : Float(*, 256, 32, 32, strides=[262144, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%509) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %512 : Float(*, 512, 32, 32, strides=[524288, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%352, %513, %514)
#   %355 : Float(*, 512, 32, 32, strides=[524288, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Add(%512, %346) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %515 : Float(*, 256, 32, 32, strides=[262144, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%355, %516, %517)
#   %358 : Float(*, 256, 32, 32, strides=[262144, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%515) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %518 : Float(*, 256, 32, 32, strides=[262144, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%358, %519, %520)
#   %361 : Float(*, 256, 32, 32, strides=[262144, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%518) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %521 : Float(*, 512, 32, 32, strides=[524288, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%361, %522, %523)
#   %364 : Float(*, 512, 32, 32, strides=[524288, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Add(%521, %355) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %524 : Float(*, 256, 32, 32, strides=[262144, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%364, %525, %526)
#   %367 : Float(*, 256, 32, 32, strides=[262144, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%524) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %527 : Float(*, 256, 32, 32, strides=[262144, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%367, %528, %529)
#   %370 : Float(*, 256, 32, 32, strides=[262144, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%527) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %530 : Float(*, 512, 32, 32, strides=[524288, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%370, %531, %532)
#   %373 : Float(*, 512, 32, 32, strides=[524288, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Add(%530, %364) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %533 : Float(*, 512, 32, 32, strides=[524288, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%373, %534, %535)
#   %376 : Float(*, 512, 32, 32, strides=[524288, 1024, 32, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%533) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %536 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%376, %537, %538)
#   %379 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%536) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %539 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%379, %540, %541)
#   %382 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%373, %conv4.dens_layer_0.conv_shortcut.weight, %conv4.dens_layer_0.conv_shortcut.bias) # /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py:443:0
#   %383 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Add(%539, %382) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %542 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%383, %543, %544)
#   %386 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%542) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %545 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%386, %546, %547)
#   %389 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%545) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %548 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%389, %549, %550)
#   %392 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Add(%548, %383) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %551 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%392, %552, %553)
#   %395 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%551) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %554 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%395, %555, %556)
#   %398 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%554) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %557 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%398, %558, %559)
#   %401 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Add(%557, %392) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %560 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%401, %561, %562)
#   %404 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%560) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %563 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%404, %564, %565)
#   %407 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%563) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %566 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%407, %567, %568)
#   %410 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Add(%566, %401) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %569 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%410, %570, %571)
#   %413 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%569) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %572 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%413, %573, %574)
#   %416 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%572) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %575 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%416, %576, %577)
#   %419 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Add(%575, %410) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %578 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%419, %579, %580)
#   %422 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%578) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %581 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%422, %582, %583)
#   %425 : Float(*, 512, 16, 16, strides=[131072, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%581) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %584 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%425, %585, %586)
#   %428 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Add(%584, %419) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %587 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%428, %588, %589)
#   %431 : Float(*, 1024, 16, 16, strides=[262144, 256, 16, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%587) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %590 : Float(*, 1024, 8, 8, strides=[65536, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%431, %591, %592)
#   %434 : Float(*, 1024, 8, 8, strides=[65536, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%590) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %593 : Float(*, 2048, 8, 8, strides=[131072, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%434, %594, %595)
#   %437 : Float(*, 2048, 8, 8, strides=[131072, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[2, 2]](%428, %conv5.dens_layer_0.conv_shortcut.weight, %conv5.dens_layer_0.conv_shortcut.bias) # /opt/conda/lib/python3.7/site-packages/torch/nn/modules/conv.py:443:0
#   %438 : Float(*, 2048, 8, 8, strides=[131072, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Add(%593, %437) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %596 : Float(*, 1024, 8, 8, strides=[65536, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%438, %597, %598)
#   %441 : Float(*, 1024, 8, 8, strides=[65536, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%596) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %599 : Float(*, 1024, 8, 8, strides=[65536, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%441, %600, %601)
#   %444 : Float(*, 1024, 8, 8, strides=[65536, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%599) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %602 : Float(*, 2048, 8, 8, strides=[131072, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%444, %603, %604)
#   %447 : Float(*, 2048, 8, 8, strides=[131072, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Add(%602, %438) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %605 : Float(*, 1024, 8, 8, strides=[65536, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%447, %606, %607)
#   %450 : Float(*, 1024, 8, 8, strides=[65536, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%605) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %608 : Float(*, 1024, 8, 8, strides=[65536, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=32, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%450, %609, %610)
#   %453 : Float(*, 1024, 8, 8, strides=[65536, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Relu(%608) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1299:0
#   %611 : Float(*, 2048, 8, 8, strides=[131072, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%453, %612, %613)
#   %456 : Float(*, 2048, 8, 8, strides=[131072, 64, 8, 1], requires_grad=1, device=cuda:0) = onnx::Add(%611, %447) # /tmp/ipykernel_6513/1075430214.py:49:0
#   %457 : Float(*, 2048, 1, 1, strides=[2048, 1, 1, 1], requires_grad=1, device=cuda:0) = onnx::GlobalAveragePool(%456) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1131:0
#   %458 : Long(4, strides=[1], device=cpu) = onnx::Shape(%457)
#   %459 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %460 : Long(device=cpu) = onnx::Gather[axis=0](%458, %459) # /tmp/ipykernel_6513/1075430214.py:86:0
#   %462 : Long(1, strides=[1], device=cpu) = onnx::Unsqueeze[axes=[0]](%460)
#   %464 : Long(2, strides=[1], device=cpu) = onnx::Concat[axis=0](%462, %614)
#   %465 : Float(*, *, strides=[2048, 1], requires_grad=1, device=cuda:0) = onnx::Reshape(%457, %464) # /tmp/ipykernel_6513/1075430214.py:86:0
#   %output : Float(*, 2, strides=[2, 1], requires_grad=1, device=cuda:0) = onnx::Gemm[alpha=1., beta=1., transB=1](%465, %linear.weight, %linear.bias) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1848:0
#   return (%output)
