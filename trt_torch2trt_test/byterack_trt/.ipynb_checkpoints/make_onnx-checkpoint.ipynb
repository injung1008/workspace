# %%
import sys
sys.path.insert(0,"/DATA_17/hjjo/YOLOX_pruning/YOLOX")

import os
import time
from loguru import logger

import cv2

import torch

from yolox.data.data_augment import ValTransform
from yolox.data.datasets import COCO_CLASSES
from yolox.exp import get_exp
from yolox.utils import fuse_model, get_model_info, postprocess, vis


class YoloDetector:
    def __init__(self):
        self.exp = get_exp(None, "yolox-l")
        self.num_classes = self.exp.num_classes = 1
        self.confthre = 0.5
        self.nmsthre = 0.3
        self.test_size = self.exp.test_size
        self.rgb_means = (0.485, 0.456, 0.406)
        self.std = (0.229, 0.224, 0.225)
    

    def load(self):
        self.model = self.exp.get_model()
        logger.info("Model Summary: {}".format(get_model_info(self.model, self.exp.test_size)))
#         self.model.cuda()
#         self.model.eval()
        
        ckpt = torch.load("bytetrack_l_mot17"", map_location="cpu")
#         # load the model state dict
        self.model.load_state_dict(ckpt["model"])
  
        self.model.to('cuda').eval()
        print ('load model..')

    
max_batch_size = 1
input = torch.randn(1,3, 640, 640).cuda()


yd = YoloDetector()
yd.load()
model = yd.model
output = model(input)

print(output)


## pytorch to onnx 
torch.onnx.export(
    model,                                # model being run
    input,    # model input (or a tuple for multiple inputs)
    "bytetrack_l_mot17.onnx", # where to save the model (can be a file or file-like object)
    verbose=True, 
    opset_version=11,
    input_names = ['input'],              # the model's input names
    output_names = ['output'],
    dynamic_axes = {'input' : {0 : 'batch_size'},
                    'output' : {0 : 'batch_size'}}
)            # the model's output names
# Out:
# 2022-06-10 15:45:06.408 | INFO     | __main__:load:31 - Model Summary: Params: 99.00M, Gflops: 281.50
# load model..
# tensor([[[-5.4589e+01, -9.2660e+01,  2.0963e+02,  4.5310e+02,  1.3068e-04,
#            4.1527e-01],
#          [-2.2303e+01, -1.1825e+02,  2.1690e+02,  4.6145e+02,  5.8219e-05,
#            4.4609e-01],
#          [ 2.0776e+01, -1.0901e+02,  1.3872e+02,  3.0945e+02,  3.2042e-05,
#            4.8999e-01],
#          ...,
#          [ 5.5073e+02,  9.3971e+02,  4.1088e+02,  7.6530e+02,  1.3979e-04,
#            4.8495e-01],
#          [ 7.0071e+02,  9.4933e+02,  5.1354e+02,  8.9878e+02,  5.4809e-04,
#            5.1333e-01],
#          [ 7.4564e+02,  8.9641e+02,  4.5543e+02,  8.0349e+02,  5.3779e-04,
#            4.6534e-01]]], device='cuda:0', grad_fn=<AsStridedBackward0>)
# graph(%input : Float(*, 3, 640, 640, strides=[1228800, 409600, 640, 1], requires_grad=0, device=cuda:0),
#       %head.cls_preds.0.weight : Float(1, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %head.cls_preds.0.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0),
#       %head.cls_preds.1.weight : Float(1, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %head.cls_preds.1.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0),
#       %head.cls_preds.2.weight : Float(1, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %head.cls_preds.2.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0),
#       %head.reg_preds.0.weight : Float(4, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %head.reg_preds.0.bias : Float(4, strides=[1], requires_grad=1, device=cuda:0),
#       %head.reg_preds.1.weight : Float(4, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %head.reg_preds.1.bias : Float(4, strides=[1], requires_grad=1, device=cuda:0),
#       %head.reg_preds.2.weight : Float(4, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %head.reg_preds.2.bias : Float(4, strides=[1], requires_grad=1, device=cuda:0),
#       %head.obj_preds.0.weight : Float(1, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %head.obj_preds.0.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0),
#       %head.obj_preds.1.weight : Float(1, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %head.obj_preds.1.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0),
#       %head.obj_preds.2.weight : Float(1, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=1, device=cuda:0),
#       %head.obj_preds.2.bias : Float(1, strides=[1], requires_grad=1, device=cuda:0),
#       %1885 : Float(80, 12, 3, 3, strides=[108, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1886 : Float(80, strides=[1], requires_grad=0, device=cuda:0),
#       %1888 : Float(160, 80, 3, 3, strides=[720, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1889 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1891 : Float(80, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1892 : Float(80, strides=[1], requires_grad=0, device=cuda:0),
#       %1894 : Float(80, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1895 : Float(80, strides=[1], requires_grad=0, device=cuda:0),
#       %1897 : Float(80, 80, 1, 1, strides=[80, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1898 : Float(80, strides=[1], requires_grad=0, device=cuda:0),
#       %1900 : Float(80, 80, 3, 3, strides=[720, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1901 : Float(80, strides=[1], requires_grad=0, device=cuda:0),
#       %1903 : Float(80, 80, 1, 1, strides=[80, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1904 : Float(80, strides=[1], requires_grad=0, device=cuda:0),
#       %1906 : Float(80, 80, 3, 3, strides=[720, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1907 : Float(80, strides=[1], requires_grad=0, device=cuda:0),
#       %1909 : Float(80, 80, 1, 1, strides=[80, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1910 : Float(80, strides=[1], requires_grad=0, device=cuda:0),
#       %1912 : Float(80, 80, 3, 3, strides=[720, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1913 : Float(80, strides=[1], requires_grad=0, device=cuda:0),
#       %1915 : Float(80, 80, 1, 1, strides=[80, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1916 : Float(80, strides=[1], requires_grad=0, device=cuda:0),
#       %1918 : Float(80, 80, 3, 3, strides=[720, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1919 : Float(80, strides=[1], requires_grad=0, device=cuda:0),
#       %1921 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1922 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1924 : Float(320, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1925 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %1927 : Float(160, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1928 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1930 : Float(160, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1931 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1933 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1934 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1936 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1937 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1939 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1940 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1942 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1943 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1945 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1946 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1948 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1949 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1951 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1952 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1954 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1955 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1957 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1958 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1960 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1961 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1963 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1964 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1966 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1967 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1969 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1970 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1972 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1973 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1975 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1976 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1978 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1979 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1981 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1982 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1984 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1985 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1987 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1988 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1990 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1991 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1993 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %1994 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1996 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %1997 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %1999 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2000 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %2002 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2003 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %2005 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2006 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2008 : Float(640, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2009 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2011 : Float(320, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2012 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2014 : Float(320, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2015 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2017 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2018 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2020 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2021 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2023 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2024 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2026 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2027 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2029 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2030 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2032 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2033 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2035 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2036 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2038 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2039 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2041 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2042 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2044 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2045 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2047 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2048 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2050 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2051 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2053 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2054 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2056 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2057 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2059 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2060 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2062 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2063 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2065 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2066 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2068 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2069 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2071 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2072 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2074 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2075 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2077 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2078 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2080 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2081 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2083 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2084 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2086 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2087 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2089 : Float(640, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2090 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2092 : Float(1280, 640, 3, 3, strides=[5760, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2093 : Float(1280, strides=[1], requires_grad=0, device=cuda:0),
#       %2095 : Float(640, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2096 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2098 : Float(1280, 2560, 1, 1, strides=[2560, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2099 : Float(1280, strides=[1], requires_grad=0, device=cuda:0),
#       %2101 : Float(640, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2102 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2104 : Float(640, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2105 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2107 : Float(640, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2108 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2110 : Float(640, 640, 3, 3, strides=[5760, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2111 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2113 : Float(640, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2114 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2116 : Float(640, 640, 3, 3, strides=[5760, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2117 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2119 : Float(640, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2120 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2122 : Float(640, 640, 3, 3, strides=[5760, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2123 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2125 : Float(640, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2126 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2128 : Float(640, 640, 3, 3, strides=[5760, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2129 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2131 : Float(1280, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2132 : Float(1280, strides=[1], requires_grad=0, device=cuda:0),
#       %2134 : Float(640, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2135 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2137 : Float(320, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2138 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2140 : Float(320, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2141 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2143 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2144 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2146 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2147 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2149 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2150 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2152 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2153 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2155 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2156 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2158 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2159 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2161 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2162 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2164 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2165 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2167 : Float(640, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2168 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2170 : Float(320, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2171 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2173 : Float(160, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2174 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %2176 : Float(160, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2177 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %2179 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2180 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %2182 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2183 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %2185 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2186 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %2188 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2189 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %2191 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2192 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %2194 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2195 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %2197 : Float(160, 160, 1, 1, strides=[160, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2198 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %2200 : Float(160, 160, 3, 3, strides=[1440, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2201 : Float(160, strides=[1], requires_grad=0, device=cuda:0),
#       %2203 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2204 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2206 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2207 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2209 : Float(320, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2210 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2212 : Float(320, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2213 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2215 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2216 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2218 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2219 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2221 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2222 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2224 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2225 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2227 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2228 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2230 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2231 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2233 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2234 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2236 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2237 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2239 : Float(640, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2240 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2242 : Float(640, 640, 3, 3, strides=[5760, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2243 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2245 : Float(640, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2246 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2248 : Float(640, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2249 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2251 : Float(640, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2252 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2254 : Float(640, 640, 3, 3, strides=[5760, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2255 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2257 : Float(640, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2258 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2260 : Float(640, 640, 3, 3, strides=[5760, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2261 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2263 : Float(640, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2264 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2266 : Float(640, 640, 3, 3, strides=[5760, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2267 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2269 : Float(640, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2270 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2272 : Float(640, 640, 3, 3, strides=[5760, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2273 : Float(640, strides=[1], requires_grad=0, device=cuda:0),
#       %2275 : Float(1280, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2276 : Float(1280, strides=[1], requires_grad=0, device=cuda:0),
#       %2278 : Float(320, 320, 1, 1, strides=[320, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2279 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2281 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2282 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2284 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2285 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2287 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2288 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2290 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2291 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2293 : Float(320, 640, 1, 1, strides=[640, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2294 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2296 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2297 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2299 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2300 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2302 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2303 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2305 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2306 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2308 : Float(320, 1280, 1, 1, strides=[1280, 1, 1, 1], requires_grad=0, device=cuda:0),
#       %2309 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2311 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2312 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2314 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2315 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2317 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2318 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2320 : Float(320, 320, 3, 3, strides=[2880, 9, 3, 1], requires_grad=0, device=cuda:0),
#       %2321 : Float(320, strides=[1], requires_grad=0, device=cuda:0),
#       %2322 : Float(4, strides=[1], requires_grad=0, device=cpu),
#       %2323 : Float(4, strides=[1], requires_grad=0, device=cpu)):
#   %895 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %896 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %897 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %898 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %899 : Float(*, 3, 320, 640, strides=[1228800, 409600, 1280, 1], requires_grad=0, device=cuda:0) = onnx::Slice(%input, %896, %897, %895, %898) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:197:0
#   %900 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %901 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %902 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %903 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %904 : Float(*, 3, 320, 320, strides=[1228800, 409600, 1280, 2], requires_grad=0, device=cuda:0) = onnx::Slice(%899, %901, %902, %900, %903) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:197:0
#   %905 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %906 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %907 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %908 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %909 : Float(*, 3, 320, 640, strides=[1228800, 409600, 1280, 1], requires_grad=0, device=cuda:0) = onnx::Slice(%input, %906, %907, %905, %908) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:198:0
#   %910 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %911 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %912 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %913 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %914 : Float(*, 3, 320, 320, strides=[1228800, 409600, 1280, 2], requires_grad=0, device=cuda:0) = onnx::Slice(%909, %911, %912, %910, %913) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:198:0
#   %915 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %916 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %917 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %918 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %919 : Float(*, 3, 320, 640, strides=[1228800, 409600, 1280, 1], requires_grad=0, device=cuda:0) = onnx::Slice(%input, %916, %917, %915, %918) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:199:0
#   %920 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %921 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %922 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %923 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %924 : Float(*, 3, 320, 320, strides=[1228800, 409600, 1280, 2], requires_grad=0, device=cuda:0) = onnx::Slice(%919, %921, %922, %920, %923) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:199:0
#   %925 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %926 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %927 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %928 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %929 : Float(*, 3, 320, 640, strides=[1228800, 409600, 1280, 1], requires_grad=0, device=cuda:0) = onnx::Slice(%input, %926, %927, %925, %928) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:200:0
#   %930 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %931 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %932 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %933 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %934 : Float(*, 3, 320, 320, strides=[1228800, 409600, 1280, 2], requires_grad=0, device=cuda:0) = onnx::Slice(%929, %931, %932, %930, %933) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:200:0
#   %935 : Float(*, 12, 320, 320, strides=[1228800, 102400, 320, 1], requires_grad=0, device=cuda:0) = onnx::Concat[axis=1](%904, %924, %914, %934) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:208:0
#   %1884 : Float(*, 80, 320, 320, strides=[8192000, 102400, 320, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%935, %1885, %1886)
#   %938 : Float(*, 80, 320, 320, device=cpu) = onnx::Sigmoid(%1884)
#   %939 : Float(*, 80, 320, 320, strides=[8192000, 102400, 320, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1884, %938) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1887 : Float(*, 160, 160, 160, strides=[4096000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%939, %1888, %1889)
#   %942 : Float(*, 160, 160, 160, device=cpu) = onnx::Sigmoid(%1887)
#   %943 : Float(*, 160, 160, 160, strides=[4096000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1887, %942) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1890 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%943, %1891, %1892)
#   %946 : Float(*, 80, 160, 160, device=cpu) = onnx::Sigmoid(%1890)
#   %947 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1890, %946) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1893 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%943, %1894, %1895)
#   %950 : Float(*, 80, 160, 160, device=cpu) = onnx::Sigmoid(%1893)
#   %951 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1893, %950) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1896 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%947, %1897, %1898)
#   %954 : Float(*, 80, 160, 160, device=cpu) = onnx::Sigmoid(%1896)
#   %955 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1896, %954) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1899 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%955, %1900, %1901)
#   %958 : Float(*, 80, 160, 160, device=cpu) = onnx::Sigmoid(%1899)
#   %959 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1899, %958) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %960 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Add(%959, %947) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:100:0
#   %1902 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%960, %1903, %1904)
#   %963 : Float(*, 80, 160, 160, device=cpu) = onnx::Sigmoid(%1902)
#   %964 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1902, %963) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1905 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%964, %1906, %1907)
#   %967 : Float(*, 80, 160, 160, device=cpu) = onnx::Sigmoid(%1905)
#   %968 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1905, %967) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %969 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Add(%968, %960) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:100:0
#   %1908 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%969, %1909, %1910)
#   %972 : Float(*, 80, 160, 160, device=cpu) = onnx::Sigmoid(%1908)
#   %973 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1908, %972) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1911 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%973, %1912, %1913)
#   %976 : Float(*, 80, 160, 160, device=cpu) = onnx::Sigmoid(%1911)
#   %977 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1911, %976) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %978 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Add(%977, %969) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:100:0
#   %1914 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%978, %1915, %1916)
#   %981 : Float(*, 80, 160, 160, device=cpu) = onnx::Sigmoid(%1914)
#   %982 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1914, %981) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1917 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%982, %1918, %1919)
#   %985 : Float(*, 80, 160, 160, device=cpu) = onnx::Sigmoid(%1917)
#   %986 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1917, %985) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %987 : Float(*, 80, 160, 160, strides=[2048000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Add(%986, %978) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:100:0
#   %988 : Float(*, 160, 160, 160, strides=[4096000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Concat[axis=1](%987, %951) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:184:0
#   %1920 : Float(*, 160, 160, 160, strides=[4096000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%988, %1921, %1922)
#   %991 : Float(*, 160, 160, 160, device=cpu) = onnx::Sigmoid(%1920)
#   %992 : Float(*, 160, 160, 160, strides=[4096000, 25600, 160, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1920, %991) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1923 : Float(*, 320, 80, 80, strides=[2048000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[2, 2]](%992, %1924, %1925)
#   %995 : Float(*, 320, 80, 80, device=cpu) = onnx::Sigmoid(%1923)
#   %996 : Float(*, 320, 80, 80, strides=[2048000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1923, %995) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1926 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%996, %1927, %1928)
#   %999 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1926)
#   %1000 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1926, %999) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1929 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%996, %1930, %1931)
#   %1003 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1929)
#   %1004 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1929, %1003) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1932 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1000, %1933, %1934)
#   %1007 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1932)
#   %1008 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1932, %1007) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1935 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1008, %1936, %1937)
#   %1011 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1935)
#   %1012 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1935, %1011) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1013 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Add(%1012, %1000) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:100:0
#   %1938 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1013, %1939, %1940)
#   %1016 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1938)
#   %1017 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1938, %1016) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1941 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1017, %1942, %1943)
#   %1020 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1941)
#   %1021 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1941, %1020) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1022 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Add(%1021, %1013) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:100:0
#   %1944 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1022, %1945, %1946)
#   %1025 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1944)
#   %1026 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1944, %1025) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1947 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1026, %1948, %1949)
#   %1029 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1947)
#   %1030 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1947, %1029) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1031 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Add(%1030, %1022) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:100:0
#   %1950 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1031, %1951, %1952)
#   %1034 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1950)
#   %1035 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1950, %1034) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1953 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1035, %1954, %1955)
#   %1038 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1953)
#   %1039 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1953, %1038) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1040 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Add(%1039, %1031) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:100:0
#   %1956 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1040, %1957, %1958)
#   %1043 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1956)
#   %1044 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1956, %1043) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1959 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1044, %1960, %1961)
#   %1047 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1959)
#   %1048 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1959, %1047) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1049 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Add(%1048, %1040) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:100:0
#   %1962 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1049, %1963, %1964)
#   %1052 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1962)
#   %1053 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1962, %1052) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1965 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1053, %1966, %1967)
#   %1056 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1965)
#   %1057 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1965, %1056) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1058 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Add(%1057, %1049) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:100:0
#   %1968 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1058, %1969, %1970)
#   %1061 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1968)
#   %1062 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1968, %1061) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1971 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[3, 3], pads=[1, 1, 1, 1], strides=[1, 1]](%1062, %1972, %1973)
#   %1065 : Float(*, 160, 80, 80, device=cpu) = onnx::Sigmoid(%1971)
#   %1066 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Mul(%1971, %1065) # /opt/conda/lib/python3.7/site-packages/torch/nn/functional.py:1898:0
#   %1067 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Add(%1066, %1058) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/network_blocks.py:100:0
#   %1974 : Float(*, 160, 80, 80, strides=[1024000, 6400, 80, 1], requires_grad=1, device=cuda:0) = onnx::Conv[dilations=[1, 1], group=1, kernel_shape=[1, 1], pads=[0, 0, 0, 0], strides=[1, 1]](%1067, %1975, %1976)
# ...
#   %1687 : Long(*, *, *, strides=[40, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[2]](%1686)
#   %1688 : Long(*, *, *, strides=[40, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[2]](%1682)
#   %1689 : Long(*, *, *, strides=[80, 2, 1], requires_grad=0, device=cpu) = onnx::Concat[axis=2](%1687, %1688) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:241:0
#   %1690 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1 -1  2 [ CPULongType{3} ]]()
#   %1691 : Long(1, *, 2, strides=[3200, 2, 1], requires_grad=0, device=cpu) = onnx::Reshape(%1689, %1690) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:241:0
#   %1692 : Long(device=cpu) = onnx::Cast[to=7](%1606)
#   %1693 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %1694 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %1695 : Long(*, strides=[1], requires_grad=0, device=cpu) = onnx::Range(%1693, %1692, %1694) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:240:0
#   %1696 : Long(device=cpu) = onnx::Cast[to=7](%1609)
#   %1697 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %1698 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %1699 : Long(*, strides=[1], requires_grad=0, device=cpu) = onnx::Range(%1697, %1696, %1698) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:240:0
#   %1700 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={-1}]()
#   %1701 : Long(*, device=cpu) = onnx::Reshape(%1695, %1700)
#   %1702 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={-1}]()
#   %1703 : Long(*, device=cpu) = onnx::Reshape(%1699, %1702)
#   %1704 : Long(1, strides=[1], device=cpu) = onnx::Shape(%1701)
#   %1705 : Long(1, strides=[1], device=cpu) = onnx::Shape(%1703)
#   %1706 : Long(2, strides=[1], device=cpu) = onnx::Concat[axis=0](%1704, %1705)
#   %1707 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %1708 : Long(2, strides=[1], device=cpu) = onnx::Concat[axis=0](%1704, %1707)
#   %1709 : Long(*, *, device=cpu) = onnx::Reshape(%1701, %1708)
#   %1710 : LongTensor(device=cpu) = onnx::Expand(%1709, %1706)
#   %1711 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %1712 : Long(2, strides=[1], device=cpu) = onnx::Concat[axis=0](%1711, %1705)
#   %1713 : Long(*, *, device=cpu) = onnx::Reshape(%1703, %1712)
#   %1714 : LongTensor(device=cpu) = onnx::Expand(%1713, %1706)
#   %1715 : Long(*, *, *, strides=[20, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[2]](%1714)
#   %1716 : Long(*, *, *, strides=[20, 1, 1], device=cpu) = onnx::Unsqueeze[axes=[2]](%1710)
#   %1717 : Long(*, *, *, strides=[40, 2, 1], requires_grad=0, device=cpu) = onnx::Concat[axis=2](%1715, %1716) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:241:0
#   %1718 : Long(3, strides=[1], device=cpu) = onnx::Constant[value= 1 -1  2 [ CPULongType{3} ]]()
#   %1719 : Long(1, *, 2, strides=[800, 2, 1], requires_grad=0, device=cpu) = onnx::Reshape(%1717, %1718) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:241:0
#   %1720 : Long(1, *, 2, strides=[16800, 2, 1], requires_grad=0, device=cpu) = onnx::Concat[axis=1](%1663, %1691, %1719) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:246:0
#   %1721 : Float(1, *, 2, strides=[16800, 2, 1], requires_grad=0, device=cuda:0) = onnx::Cast[to=1](%1720) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:246:0
#   %1722 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %1723 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %1724 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %1725 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %1726 : Float(*, *, *, strides=[50400, 1, 8400], requires_grad=1, device=cuda:0) = onnx::Slice(%1635, %1723, %1724, %1722, %1725) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:249:0
#   %1727 : Float(*, *, *, strides=[16800, 1, 8400], requires_grad=1, device=cuda:0) = onnx::Add(%1726, %1721) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:249:0
#   %1728 : Float(1, 8400, 1, strides=[8400, 1, 1], requires_grad=0, device=cpu) = onnx::Constant[value=<Tensor>]()
#   %1729 : Float(*, *, *, strides=[16800, 1, 8400], requires_grad=1, device=cuda:0) = onnx::Mul(%1727, %1728) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:249:0
#   %1730 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %1731 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %1732 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %1733 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %1734 : Float(*, *, *, strides=[50400, 1, 8400], requires_grad=1, device=cuda:0) = onnx::Slice(%1635, %1731, %1732, %1730, %1733) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:249:0
#   %1735 : Long(3, strides=[1], device=cpu) = onnx::Shape(%1734)
#   %1736 : Float(1, 8400, 2, strides=[16800, 1, 8400], requires_grad=1, device=cuda:0) = onnx::Expand(%1729, %1735) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:249:0
#   %1737 : Long(3, strides=[1], device=cpu) = onnx::Shape(%1635)
#   %1738 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %1739 : Long(device=cpu) = onnx::Gather[axis=0](%1737, %1738)
#   %1740 : Long(device=cpu) = onnx::Cast[to=7](%1739)
#   %1741 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %1742 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %1743 : Long(*, device=cpu) = onnx::Range(%1741, %1740, %1742)
#   %1744 : Long(3, strides=[1], device=cpu) = onnx::Shape(%1635)
#   %1745 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %1746 : Long(device=cpu) = onnx::Gather[axis=0](%1744, %1745)
#   %1747 : Long(device=cpu) = onnx::Cast[to=7](%1746)
#   %1748 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %1749 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %1750 : Long(*, device=cpu) = onnx::Range(%1748, %1747, %1749)
#   %1751 : Long(3, strides=[1], device=cpu) = onnx::Shape(%1635)
#   %1752 : Long(device=cpu) = onnx::Constant[value={2}]()
#   %1753 : Long(device=cpu) = onnx::Gather[axis=0](%1751, %1752)
#   %1754 : Long(device=cpu) = onnx::Cast[to=7](%1753)
#   %1755 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %1756 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %1757 : Long(*, device=cpu) = onnx::Range(%1755, %1754, %1756)
#   %1758 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %1759 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %1760 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %1761 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %1762 : Long(*, device=cpu) = onnx::Slice(%1757, %1759, %1760, %1758, %1761)
#   %1763 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=-1  1  1 [ CPULongType{3} ]]()
#   %1764 : Long(*, 1, 1, device=cpu) = onnx::Reshape(%1743, %1763)
#   %1765 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %1766 : Long(*, 1, device=cpu) = onnx::Reshape(%1750, %1765)
#   %1767 : Long(*, *, 1, device=cpu) = onnx::Add(%1764, %1766)
#   %1768 : Long(*, *, *, device=cpu) = onnx::Add(%1767, %1762)
#   %1769 : Long(3, strides=[1], device=cpu) = onnx::Shape(%1768)
#   %1770 : Long(1, strides=[1], device=cpu) = onnx::Shape(%1769)
#   %1771 : Long(3, device=cpu) = onnx::ConstantOfShape[value={1}](%1770)
#   %1772 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %1773 : Long(3, strides=[1], device=cpu) = onnx::Mul(%1771, %1772)
#   %1774 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%1769, %1773)
#   %1775 : Long(3, strides=[1], device=cpu) = onnx::Where(%1774, %1771, %1769)
#   %1776 : LongTensor(device=cpu) = onnx::Expand(%1764, %1775)
#   %1777 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%1776)
#   %1778 : Long(1, strides=[1], device=cpu) = onnx::Shape(%1769)
#   %1779 : Long(3, device=cpu) = onnx::ConstantOfShape[value={1}](%1778)
#   %1780 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %1781 : Long(3, strides=[1], device=cpu) = onnx::Mul(%1779, %1780)
#   %1782 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%1769, %1781)
#   %1783 : Long(3, strides=[1], device=cpu) = onnx::Where(%1782, %1779, %1769)
#   %1784 : LongTensor(device=cpu) = onnx::Expand(%1766, %1783)
#   %1785 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%1784)
#   %1786 : Long(1, strides=[1], device=cpu) = onnx::Shape(%1769)
#   %1787 : Long(3, device=cpu) = onnx::ConstantOfShape[value={1}](%1786)
#   %1788 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %1789 : Long(3, strides=[1], device=cpu) = onnx::Mul(%1787, %1788)
#   %1790 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%1769, %1789)
#   %1791 : Long(3, strides=[1], device=cpu) = onnx::Where(%1790, %1787, %1769)
#   %1792 : LongTensor(device=cpu) = onnx::Expand(%1762, %1791)
#   %1793 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%1792)
#   %1794 : LongTensor(device=cpu) = onnx::Concat[axis=-1](%1777, %1785, %1793)
#   %1795 : Long(3, strides=[1], device=cpu) = onnx::Shape(%1635)
#   %1796 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %1797 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %1798 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %1799 : Long(0, strides=[1], device=cpu) = onnx::Slice(%1795, %1797, %1798, %1796)
#   %1800 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0](%1769, %1799)
#   %1801 : Float(*, *, *, device=cpu) = onnx::Reshape(%1736, %1800)
#   %1802 : Float(*, *, *, strides=[50400, 1, 8400], requires_grad=1, device=cuda:0) = onnx::ScatterND(%1635, %1794, %1801) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:249:0
#   %1803 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %1804 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %1805 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={4}]()
#   %1806 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %1807 : Float(*, *, *, strides=[50400, 1, 8400], requires_grad=1, device=cuda:0) = onnx::Slice(%1802, %1804, %1805, %1803, %1806) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:250:0
#   %1808 : Float(*, *, *, strides=[50400, 1, 8400], requires_grad=1, device=cuda:0) = onnx::Exp(%1807) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:250:0
#   %1809 : Float(1, 8400, 1, strides=[8400, 1, 1], requires_grad=0, device=cpu) = onnx::Constant[value=<Tensor>]()
#   %1810 : Float(*, *, *, strides=[16800, 1, 8400], requires_grad=1, device=cuda:0) = onnx::Mul(%1808, %1809) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:250:0
#   %1811 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %1812 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %1813 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={4}]()
#   %1814 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %1815 : Float(*, *, *, strides=[50400, 1, 8400], requires_grad=1, device=cuda:0) = onnx::Slice(%1802, %1812, %1813, %1811, %1814) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:250:0
#   %1816 : Long(3, strides=[1], device=cpu) = onnx::Shape(%1815)
#   %1817 : Float(1, 8400, 2, strides=[16800, 1, 8400], requires_grad=1, device=cuda:0) = onnx::Expand(%1810, %1816) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:250:0
#   %1818 : Long(3, strides=[1], device=cpu) = onnx::Shape(%1802)
#   %1819 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %1820 : Long(device=cpu) = onnx::Gather[axis=0](%1818, %1819)
#   %1821 : Long(device=cpu) = onnx::Cast[to=7](%1820)
#   %1822 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %1823 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %1824 : Long(*, device=cpu) = onnx::Range(%1822, %1821, %1823)
#   %1825 : Long(3, strides=[1], device=cpu) = onnx::Shape(%1802)
#   %1826 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %1827 : Long(device=cpu) = onnx::Gather[axis=0](%1825, %1826)
#   %1828 : Long(device=cpu) = onnx::Cast[to=7](%1827)
#   %1829 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %1830 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %1831 : Long(*, device=cpu) = onnx::Range(%1829, %1828, %1830)
#   %1832 : Long(3, strides=[1], device=cpu) = onnx::Shape(%1802)
#   %1833 : Long(device=cpu) = onnx::Constant[value={2}]()
#   %1834 : Long(device=cpu) = onnx::Gather[axis=0](%1832, %1833)
#   %1835 : Long(device=cpu) = onnx::Cast[to=7](%1834)
#   %1836 : Long(device=cpu) = onnx::Constant[value={0}]()
#   %1837 : Long(device=cpu) = onnx::Constant[value={1}]()
#   %1838 : Long(*, device=cpu) = onnx::Range(%1836, %1835, %1837)
#   %1839 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %1840 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={2}]()
#   %1841 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={4}]()
#   %1842 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={1}]()
#   %1843 : Long(*, device=cpu) = onnx::Slice(%1838, %1840, %1841, %1839, %1842)
#   %1844 : Long(3, strides=[1], device=cpu) = onnx::Constant[value=-1  1  1 [ CPULongType{3} ]]()
#   %1845 : Long(*, 1, 1, device=cpu) = onnx::Reshape(%1824, %1844)
#   %1846 : Long(2, strides=[1], device=cpu) = onnx::Constant[value=-1  1 [ CPULongType{2} ]]()
#   %1847 : Long(*, 1, device=cpu) = onnx::Reshape(%1831, %1846)
#   %1848 : Long(*, *, 1, device=cpu) = onnx::Add(%1845, %1847)
#   %1849 : Long(*, *, *, device=cpu) = onnx::Add(%1848, %1843)
#   %1850 : Long(3, strides=[1], device=cpu) = onnx::Shape(%1849)
#   %1851 : Long(1, strides=[1], device=cpu) = onnx::Shape(%1850)
#   %1852 : Long(3, device=cpu) = onnx::ConstantOfShape[value={1}](%1851)
#   %1853 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %1854 : Long(3, strides=[1], device=cpu) = onnx::Mul(%1852, %1853)
#   %1855 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%1850, %1854)
#   %1856 : Long(3, strides=[1], device=cpu) = onnx::Where(%1855, %1852, %1850)
#   %1857 : LongTensor(device=cpu) = onnx::Expand(%1845, %1856)
#   %1858 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%1857)
#   %1859 : Long(1, strides=[1], device=cpu) = onnx::Shape(%1850)
#   %1860 : Long(3, device=cpu) = onnx::ConstantOfShape[value={1}](%1859)
#   %1861 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %1862 : Long(3, strides=[1], device=cpu) = onnx::Mul(%1860, %1861)
#   %1863 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%1850, %1862)
#   %1864 : Long(3, strides=[1], device=cpu) = onnx::Where(%1863, %1860, %1850)
#   %1865 : LongTensor(device=cpu) = onnx::Expand(%1847, %1864)
#   %1866 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%1865)
#   %1867 : Long(1, strides=[1], device=cpu) = onnx::Shape(%1850)
#   %1868 : Long(3, device=cpu) = onnx::ConstantOfShape[value={1}](%1867)
#   %1869 : Long(requires_grad=0, device=cpu) = onnx::Constant[value={-1}]()
#   %1870 : Long(3, strides=[1], device=cpu) = onnx::Mul(%1868, %1869)
#   %1871 : Bool(3, strides=[1], device=cpu) = onnx::Equal(%1850, %1870)
#   %1872 : Long(3, strides=[1], device=cpu) = onnx::Where(%1871, %1868, %1850)
#   %1873 : LongTensor(device=cpu) = onnx::Expand(%1843, %1872)
#   %1874 : LongTensor(device=cpu) = onnx::Unsqueeze[axes=[-1]](%1873)
#   %1875 : LongTensor(device=cpu) = onnx::Concat[axis=-1](%1858, %1866, %1874)
#   %1876 : Long(3, strides=[1], device=cpu) = onnx::Shape(%1802)
#   %1877 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={0}]()
#   %1878 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={3}]()
#   %1879 : Long(1, strides=[1], device=cpu) = onnx::Constant[value={9223372036854775807}]()
#   %1880 : Long(0, strides=[1], device=cpu) = onnx::Slice(%1876, %1878, %1879, %1877)
#   %1881 : Long(3, strides=[1], device=cpu) = onnx::Concat[axis=0](%1850, %1880)
#   %1882 : Float(*, *, *, device=cpu) = onnx::Reshape(%1817, %1881)
#   %output : Float(*, *, *, strides=[50400, 1, 8400], requires_grad=1, device=cuda:0) = onnx::ScatterND(%1802, %1875, %1882) # /DATA_17/hjjo/YOLOX_pruning/YOLOX/yolox/models/yolo_head.py:250:0
#   return (%output)
